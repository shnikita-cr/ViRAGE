# %%
from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %%
from langchain_ollama import ChatOllama

LLM_MODEL = "qwen3-coder:480b-cloud"  # или "llama3.2:1b"
llm = ChatOllama(
    model=LLM_MODEL,
    temperature=0,
)

# %%
llm.invoke("Hi")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'model': 'qwen3-coder:480b', 'created_at': '2026-04-26T22:41:11.614376835Z', 'done': True, 'done_reason': 'stop', 'total_duration': 22727371253, 'load_duration': None, 'prompt_eval_count': 9, 'prompt_eval_duration': None, 'eval_count': 10, 'eval_duration': None, 'logprobs': None, 'model_name': 'qwen3-coder:480b', 'model_provider': 'ollama'}, id='lc_run--019dcbf3-d7bc-72f1-a134-9433508922e1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 10, 'total_tokens': 19})

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7
)
llm.invoke("hi!")
