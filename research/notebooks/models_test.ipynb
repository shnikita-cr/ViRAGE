# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# True

# %%
from langchain_ollama import ChatOllama

LLM_MODEL = "gemma4:31b-cloud"  # или "llama3.2:1b"
llm = ChatOllama(
    model=LLM_MODEL,
    base_url="http://localhost:11434",
    temperature=0,
)

# %%
llm.invoke("Hi")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'model': 'gemma4:31b', 'created_at': '2026-05-27T12:56:42.645184976Z', 'done': True, 'done_reason': 'stop', 'total_duration': 637779084, 'load_duration': None, 'prompt_eval_count': 14, 'prompt_eval_duration': None, 'eval_count': 10, 'eval_duration': None, 'logprobs': None, 'model_name': 'gemma4:31b'}, id='run--019e6982-379b-7d90-8426-9fc9140f0f0f-0', usage_metadata={'input_tokens': 14, 'output_tokens': 10, 'total_tokens': 24})

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7
)
llm.invoke("hi!")
