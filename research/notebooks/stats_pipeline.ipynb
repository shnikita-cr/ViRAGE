# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../../artifacts/global_analysis.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 75 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   run_id                                           62 non-null     object
#  1   run_path                                         62 non-null     object
#  2   run_path_abs                                     62 non-null     object
#  3   started_at                                       53 non-null     object
#  4   finished_at                                      62 non-null     object
#  5   duration_seconds                                 53 non-null     float64
#  6   status                                           62 non-null     object
#  7   is_success                                       62 non-null     bool
#  8   has_errors                                       62 non-null     bool
#  9   error_count                                      62 non-null     int64
#  10  first_error                                      41 non-null     object
#  11  query                                            61 non-null     object
#  12  stage_count                                      62 non-null     int64
#  13  stage_succeeded_count                            62 non-null     int64
#  14  stage_failed_count                               62 non-null     int64
#  15  stage_skipped_count                              62 non-null     int64
#  16  stage_names                                      7 non-null      object
#  17  failed_stage                                     5 non-null      object
#  18  model_call_count                                 62 non-null     int64
#  19  model_call_stage_names                           60 non-null     object
#  20  model_call_roles                                 60 non-null     object
#  21  model_call_models                                60 non-null     object
#  22  model_call_prompt_tokens                         62 non-null     int64
#  23  model_call_completion_tokens                     62 non-null     int64
#  24  model_call_total_tokens                          62 non-null     int64
#  25  model_call_duration_seconds                      62 non-null     float64
#  26  model_call_error_count                           62 non-null     int64
#  27  has_png                                          62 non-null     bool
#  28  has_plot_png                                     62 non-null     bool
#  29  png_count                                        62 non-null     int64
#  30  plot_png_path                                    26 non-null     object
#  31  has_spec_validation                              62 non-null     bool
#  32  spec_is_valid                                    35 non-null     object
#  33  spec_validation_error_count                      35 non-null     float64
#  34  selected_spec_id                                 0 non-null      float64
#  35  selected_chart_family                            0 non-null      float64
#  36  selected_candidate_score                         0 non-null      float64
#  37  vega_mark                                        0 non-null      float64
#  38  vega_encoding_channels                           0 non-null      float64
#  39  prepared_data_path                               38 non-null     object
#  40  prepared_row_count                               38 non-null     float64
#  41  prepared_col_count                               38 non-null     float64
#  42  has_structural_spec_metric                       62 non-null     bool
#  43  has_visual_quality_metric                        62 non-null     bool
#  44  has_evaluation_summary                           62 non-null     bool
#  45  json_file_count                                  62 non-null     int64
#  46  csv_file_count                                   62 non-null     int64
#  47  total_file_count                                 62 non-null     int64
#  48  total_size_bytes                                 62 non-null     int64
#  49  stage_logs_json                                  62 non-null     object
#  50  model_calls_json                                 62 non-null     object
#  51  png_paths_json                                   62 non-null     object
#  52  spec_validation_path                             35 non-null     object
#  53  spec_validation_json                             35 non-null     object
#  54  artifact_paths_json                              62 non-null     object
#  55  errors_json                                      62 non-null     object
#  56  query_path                                       61 non-null     object
#  57  user_context_json                                61 non-null     object
#  58  data_preparation_json                            38 non-null     object
#  59  structural_spec_metric_json                      8 non-null      object
#  60  structural_spec_metric_score                     8 non-null      float64
#  61  structural_spec_metric_mark_score                8 non-null      float64
#  62  structural_spec_metric_encoding_score            8 non-null      float64
#  63  structural_spec_metric_transform_score           8 non-null      float64
#  64  structural_spec_metric_task_alignment_score      8 non-null      float64
#  65  visual_quality_metric_json                       16 non-null     object
#  66  visual_quality_metric_score                      16 non-null     float64
#  67  visual_quality_metric_prompt_compliance          16 non-null     float64
#  68  visual_quality_metric_readability                16 non-null     float64
#  69  visual_quality_metric_insight_supportiveness     16 non-null     float64
#  70  evaluation_summary_json                          16 non-null     object
#  71  evaluation_summary_structural_spec_metric        8 non-null      float64
#  72  evaluation_summary_visual_quality_metric         16 non-null     float64
#  73  evaluation_summary_empty_chart_status            16 non-null     object
#  74  evaluation_summary_insight_verification_summary  16 non-null     object
# dtypes: bool(8), float64(21), int64(15), object(31)
# memory usage: 33.1+ KB

# %%
for column in df.select_dtypes(["bool"]).columns:
    df[column] = df[column].astype(int)

# %%
df.describe().T
# Out:
#                                               count           mean  \
# duration_seconds                               53.0       7.894865
# is_success                                     62.0       0.032258
# has_errors                                     62.0       0.661290
# error_count                                    62.0       0.822581
# stage_count                                    62.0       0.983871
# stage_succeeded_count                          62.0       0.838710
# stage_failed_count                             62.0       0.080645
# stage_skipped_count                            62.0       0.064516
# model_call_count                               62.0       6.677419
# model_call_prompt_tokens                       62.0    7439.387097
# model_call_completion_tokens                   62.0    2000.112903
# model_call_total_tokens                        62.0    9439.500000
# model_call_duration_seconds                    62.0      65.459221
# model_call_error_count                         62.0       0.919355
# has_png                                        62.0       0.419355
# has_plot_png                                   62.0       0.419355
# png_count                                      62.0       0.419355
# has_spec_validation                            62.0       0.564516
# spec_validation_error_count                    35.0       0.342857
# selected_spec_id                                0.0            NaN
# selected_chart_family                           0.0            NaN
# selected_candidate_score                        0.0            NaN
# vega_mark                                       0.0            NaN
# vega_encoding_channels                          0.0            NaN
# prepared_row_count                             38.0    1090.421053
# prepared_col_count                             38.0       4.736842
# has_structural_spec_metric                     62.0       0.129032
# has_visual_quality_metric                      62.0       0.258065
# has_evaluation_summary                         62.0       0.258065
# json_file_count                                62.0      16.725806
# csv_file_count                                 62.0       2.532258
# total_file_count                               62.0      21.483871
# total_size_bytes                               62.0  643910.370968
# structural_spec_metric_score                    8.0       0.779375
# structural_spec_metric_mark_score               8.0       1.000000
# structural_spec_metric_encoding_score           8.0       0.550000
# structural_spec_metric_transform_score          8.0       0.812500
# structural_spec_metric_task_alignment_score     8.0       0.937500
# visual_quality_metric_score                    16.0       0.853444
# visual_quality_metric_prompt_compliance        16.0       0.875000
# visual_quality_metric_readability              16.0       0.875000
# visual_quality_metric_insight_supportiveness   16.0       0.750000
# evaluation_summary_structural_spec_metric       8.0       0.779375
# evaluation_summary_visual_quality_metric       16.0       0.853444
#
#                                                        std     min  \
# duration_seconds                              3.507755e+01   0.000
# is_success                                    1.781270e-01   0.000
# has_errors                                    4.771345e-01   0.000
# error_count                                   6.900747e-01   0.000
# stage_count                                   3.494689e+00   0.000
# stage_succeeded_count                         3.100468e+00   0.000
# stage_failed_count                            2.745122e-01   0.000
# stage_skipped_count                           2.476756e-01   0.000
# model_call_count                              6.177097e+00   0.000
# model_call_prompt_tokens                      7.695276e+03   0.000
# model_call_completion_tokens                  2.239794e+03   0.000
# model_call_total_tokens                       9.437892e+03   0.000
# model_call_duration_seconds                   8.758265e+01   0.000
# model_call_error_count                        1.358620e+00   0.000
# has_png                                       4.974818e-01   0.000
# has_plot_png                                  4.974818e-01   0.000
# png_count                                     4.974818e-01   0.000
# has_spec_validation                           4.998678e-01   0.000
# spec_validation_error_count                   5.912528e-01   0.000
# selected_spec_id                                       NaN     NaN
# selected_chart_family                                  NaN     NaN
# selected_candidate_score                               NaN     NaN
# vega_mark                                              NaN     NaN
# vega_encoding_channels                                 NaN     NaN
# prepared_row_count                            1.653478e+03   9.000
# prepared_col_count                            2.872838e+00   1.000
# has_structural_spec_metric                    3.379723e-01   0.000
# has_visual_quality_metric                     4.411417e-01   0.000
# has_evaluation_summary                        4.411417e-01   0.000
# json_file_count                               1.255698e+01   0.000
# csv_file_count                                1.082161e+00   0.000
# total_file_count                              1.311330e+01   2.000
# total_size_bytes                              1.339143e+06  70.000
# structural_spec_metric_score                  7.138615e-02   0.685
# structural_spec_metric_mark_score             0.000000e+00   1.000
# structural_spec_metric_encoding_score         2.070197e-01   0.400
# structural_spec_metric_transform_score        2.587746e-01   0.500
# structural_spec_metric_task_alignment_score   1.767767e-01   0.500
# visual_quality_metric_score                   2.845562e-01   0.000
# visual_quality_metric_prompt_compliance       2.886751e-01   0.000
# visual_quality_metric_readability             2.886751e-01   0.000
# visual_quality_metric_insight_supportiveness  3.651484e-01   0.000
# evaluation_summary_structural_spec_metric     7.138615e-02   0.685
# evaluation_summary_visual_quality_metric      2.845562e-01   0.000
#
#                                                        25%            50%  \
# duration_seconds                                  0.000000       0.000000
# is_success                                        0.000000       0.000000
# has_errors                                        0.000000       1.000000
# error_count                                       0.000000       1.000000
# stage_count                                       0.000000       0.000000
# stage_succeeded_count                             0.000000       0.000000
# stage_failed_count                                0.000000       0.000000
# stage_skipped_count                               0.000000       0.000000
# model_call_count                                  2.000000       4.000000
# model_call_prompt_tokens                       1672.500000    4432.000000
# model_call_completion_tokens                      0.000000    1635.000000
# model_call_total_tokens                        1672.500000    6174.000000
# model_call_duration_seconds                       3.053596      25.342292
# model_call_error_count                            0.000000       0.000000
# has_png                                           0.000000       0.000000
# has_plot_png                                      0.000000       0.000000
# png_count                                         0.000000       0.000000
# has_spec_validation                               0.000000       1.000000
# spec_validation_error_count                       0.000000       0.000000
# selected_spec_id                                       NaN            NaN
# selected_chart_family                                  NaN            NaN
# selected_candidate_score                               NaN            NaN
# vega_mark                                              NaN            NaN
# vega_encoding_channels                                 NaN            NaN
# prepared_row_count                              150.000000     150.000000
# prepared_col_count                                2.000000       5.000000
# has_structural_spec_metric                        0.000000       0.000000
# has_visual_quality_metric                         0.000000       0.000000
# has_evaluation_summary                            0.000000       0.000000
# json_file_count                                   4.000000      12.000000
# csv_file_count                                    2.000000       3.000000
# total_file_count                                  8.000000      18.000000
# total_size_bytes                              18641.250000  148664.000000
# structural_spec_metric_score                      0.756250       0.760000
# structural_spec_metric_mark_score                 1.000000       1.000000
# structural_spec_metric_encoding_score             0.400000       0.400000
# structural_spec_metric_transform_score            0.500000       1.000000
# structural_spec_metric_task_alignment_score       1.000000       1.000000
# visual_quality_metric_score                       0.905150       1.000000
# visual_quality_metric_prompt_compliance           1.000000       1.000000
# visual_quality_metric_readability                 1.000000       1.000000
# visual_quality_metric_insight_supportiveness      0.500000       1.000000
# evaluation_summary_structural_spec_metric         0.756250       0.760000
# evaluation_summary_visual_quality_metric          0.905150       1.000000
#
#                                                         75%           max
# duration_seconds                                   0.000000  2.483766e+02
# is_success                                         0.000000  1.000000e+00
# has_errors                                         1.000000  1.000000e+00
# error_count                                        1.000000  2.000000e+00
# stage_count                                        0.000000  1.900000e+01
# stage_succeeded_count                              0.000000  1.800000e+01
# stage_failed_count                                 0.000000  1.000000e+00
# stage_skipped_count                                0.000000  1.000000e+00
# model_call_count                                  12.000000  2.400000e+01
# model_call_prompt_tokens                       11013.000000  3.137800e+04
# model_call_completion_tokens                    3738.000000  1.225200e+04
# model_call_total_tokens                        14846.000000  3.797600e+04
# model_call_duration_seconds                       94.634653  3.828317e+02
# model_call_error_count                             2.000000  8.000000e+00
# has_png                                            1.000000  1.000000e+00
# has_plot_png                                       1.000000  1.000000e+00
# png_count                                          1.000000  1.000000e+00
# has_spec_validation                                1.000000  1.000000e+00
# spec_validation_error_count                        1.000000  2.000000e+00
# selected_spec_id                                        NaN           NaN
# selected_chart_family                                   NaN           NaN
# selected_candidate_score                                NaN           NaN
# vega_mark                                               NaN           NaN
# vega_encoding_channels                                  NaN           NaN
# prepared_row_count                              2737.500000  5.400000e+03
# prepared_col_count                                 5.750000  1.000000e+01
# has_structural_spec_metric                         0.000000  1.000000e+00
# has_visual_quality_metric                          0.750000  1.000000e+00
# has_evaluation_summary                             0.750000  1.000000e+00
# json_file_count                                   30.000000  4.900000e+01
# csv_file_count                                     3.000000  5.000000e+00
# total_file_count                                  35.000000  5.600000e+01
# total_size_bytes                              422311.250000  5.729071e+06
# structural_spec_metric_score                       0.781250  9.200000e-01
# structural_spec_metric_mark_score                  1.000000  1.000000e+00
# structural_spec_metric_encoding_score              0.800000  8.000000e-01
# structural_spec_metric_transform_score             1.000000  1.000000e+00
# structural_spec_metric_task_alignment_score        1.000000  1.000000e+00
# visual_quality_metric_score                        1.000000  1.000000e+00
# visual_quality_metric_prompt_compliance            1.000000  1.000000e+00
# visual_quality_metric_readability                  1.000000  1.000000e+00
# visual_quality_metric_insight_supportiveness       1.000000  1.000000e+00
# evaluation_summary_structural_spec_metric          0.781250  9.200000e-01
# evaluation_summary_visual_quality_metric           1.000000  1.000000e+00

# %%
# df.filter(regex="stage.*").describe().plot(kind="hist")

# %%
for column in df.select_dtypes(exclude=["object"]).columns:
    print(column)
    df[column].plot(kind="hist", bins=15)
    plt.show()
# Out:
# duration_seconds
# is_success
# has_errors
# error_count
# stage_count
# stage_succeeded_count
# stage_failed_count
# stage_skipped_count
# model_call_count
# model_call_prompt_tokens
# model_call_completion_tokens
# model_call_total_tokens
# model_call_duration_seconds
# model_call_error_count
# has_png
# has_plot_png
# png_count
# has_spec_validation
# spec_validation_error_count
# selected_spec_id
# selected_chart_family
# selected_candidate_score
# vega_mark
# vega_encoding_channels
# prepared_row_count
# prepared_col_count
# has_structural_spec_metric
# has_visual_quality_metric
# has_evaluation_summary
# json_file_count
# csv_file_count
# total_file_count
# total_size_bytes
# structural_spec_metric_score
# structural_spec_metric_mark_score
# structural_spec_metric_encoding_score
# structural_spec_metric_transform_score
# structural_spec_metric_task_alignment_score
# visual_quality_metric_score
# visual_quality_metric_prompt_compliance
# visual_quality_metric_readability
# visual_quality_metric_insight_supportiveness
# evaluation_summary_structural_spec_metric
# evaluation_summary_visual_quality_metric
