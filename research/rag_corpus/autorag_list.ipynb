# %%
import pandas as pd;
from rich import print as rprint

pd.set_option('display.max_columns', None);
pd.set_option('display.width', 200);
pd.set_option('display.max_colwidth', 300);

# %%
df = pd.read_parquet('../../rag_corpus/autorag/virage_rules/corpus.parquet');
df.head(10)
# Out:
#                                                                                             doc_id  \
# 0  chart_pattern__vega_lite_examples__interactive_visualization_of_connections_among_m__2f1ec46b3c
# 1                  chart_pattern__vega_lite_examples__animated_gapminder_chart_pattern__d48defe6fd
# 2                                  chart_pattern__vega_lite_examples__simple_pie_chart__5ae2bd8cab
# 3                               chart_pattern__vega_lite_examples__donut_chart_pattern__0fc47ca19d
# 4                   chart_pattern__vega_lite_examples__arc_ordinal_theta_chart_pattern__2784d9e0eb
# 5                 chart_pattern__vega_lite_examples__pie_chart_with_percentage_tooltip__482195a932
# 6                         chart_pattern__vega_lite_examples__pyramid_pie_chart_pattern__f4a298f489
# 7                              chart_pattern__vega_lite_examples__radial_chart_pattern__d209ecb70c
# 8                      chart_pattern__vega_lite_examples__arc_radial_histogram_pattern__e087415edf
# 9                                chart_pattern__vega_lite_examples__area_chart_pattern__1ab7cde47e
#
#                                                                                                                                                                                                                                                                                                       contents  \
# 0  Title: Interactive Visualization of Connections Among Major U.S. Airports\nType: chart_pattern\nTask: Create an interactive visualization showing connections among major U.S. airports in 2008.\nChart family: network_graph\nApplies when: When visualizing connections between entities like airports...
# 1  Title: Animated Gapminder Chart Pattern\nType: chart_pattern\nTask: Create an animated chart to visualize global population growth over time.\nChart family: line_chart\nApplies when: When creating a visualization that shows trends over time for multiple categories.\nGuidance: Use a line chart wi...
# 2  Title: Simple Pie Chart\nType: chart_pattern\nTask: Create a pie chart to display proportions of categories.\nChart family: pie_chart\nApplies when: When data consists of categorical values and their corresponding numerical values.\nGuidance: Use a pie chart to show the proportion of each catego...
# 3  Title: Donut Chart Pattern\nType: chart_pattern\nTask: Create a donut chart to show proportions of categories.\nChart family: pie_chart\nApplies when: When showing parts of a whole with varying proportions.\nGuidance: Use a donut chart for visualizing categorical data where the sum of all catego...
# 4  Title: Arc Ordinal Theta Chart Pattern\nType: chart_pattern\nTask: Create a chart that represents data using arcs with ordinal theta values.\nChart family: arc_chart\nApplies when: When the data is categorical and you want to represent it in a circular format.\nGuidance: Use an arc chart to disp...
# 5  Title: Pie Chart with Percentage Tooltip\nType: chart_pattern\nTask: Create a pie chart that displays percentage tooltips.\nChart family: pie_chart\nApplies when: When creating a pie chart to show proportions and percentages.\nGuidance: Use the 'arc' mark type for slices. Include a tooltip layer...
# 6  Title: Pyramid Pie Chart Pattern\nType: chart_pattern\nTask: Create a pyramid pie chart to compare parts of a whole.\nChart family: pie_chart\nApplies when: When comparing parts of a whole with hierarchical data.\nGuidance: Use a single color for the entire dataset and vary shades or patterns wi...
# 7  Title: Radial Chart Pattern\nType: chart_pattern\nTask: Create a radial chart to represent data in a circular format.\nChart family: radial\nApplies when: When you want to display data in a circular or polar coordinate system.\nGuidance: Use radial charts for data that is naturally suited to a c...
# 8  Title: Arc Radial Histogram Pattern\nType: chart_pattern\nTask: Create a radial histogram chart to visualize data distribution around a central point.\nChart family: radial_histogram\nApplies when: When you need to show the distribution of data points in a circular format, with each arc represen...
# 9  Title: Area Chart Pattern\nType: chart_pattern\nTask: Ensure the chart effectively represents area data.\nChart family: area\nApplies when: When creating an area chart.\nGuidance: Use a continuous color gradient to represent varying areas.\nAvoid: Avoid using solid colors for all areas.\nRetriev...
#
#                                                                                                                                                                                                                               metadata
# 0  {"chart_family": "network_graph", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create an interactive visualization showing connections among major U.S. airports in 2008."}
# 1                      {"chart_family": "line_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create an animated chart to visualize global population growth over time."}
# 2                                        {"chart_family": "pie_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a pie chart to display proportions of categories."}
# 3                                         {"chart_family": "pie_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a donut chart to show proportions of categories."}
# 4                       {"chart_family": "arc_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a chart that represents data using arcs with ordinal theta values."}
# 5                                           {"chart_family": "pie_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a pie chart that displays percentage tooltips."}
# 6                                         {"chart_family": "pie_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a pyramid pie chart to compare parts of a whole."}
# 7                                      {"chart_family": "radial", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a radial chart to represent data in a circular format."}
# 8   {"chart_family": "radial_histogram", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a radial histogram chart to visualize data distribution around a central point."}
# 9                                                   {"chart_family": "area", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Ensure the chart effectively represents area data."}

# %%
print(df.iloc[5].to_dict())
# Out:
# {'doc_id': 'chart_pattern__vega_lite_examples__pie_chart_with_percentage_tooltip__482195a932', 'contents': "Title: Pie Chart with Percentage Tooltip\nType: chart_pattern\nTask: Create a pie chart that displays percentage tooltips.\nChart family: pie_chart\nApplies when: When creating a pie chart to show proportions and percentages.\nGuidance: Use the 'arc' mark type for slices. Include a tooltip layer with percentage values.\nAvoid: Avoid using overlapping labels or legends that might obscure the data.\nRetrieval text: pie chart percentage tooltip", 'metadata': '{"chart_family": "pie_chart", "record_type": "chart_pattern", "severity": "high", "source_dataset": "vega_lite_examples", "task": "Create a pie chart that displays percentage tooltips."}'}
